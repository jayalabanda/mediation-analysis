# %%
library(dplyr)
library(ggplot2)
library(RColorBrewer)
library(gridExtra)
library(magrittr)
# Out:
# Attaching package: 'gridExtra'
#
#
# The following object is masked from 'package:dplyr':
#
#     combine

# %%
data <- data.frame(read.csv("stremr.csv"))
data
# Out:
#   estimator     n_samples duration
# 1 g-computation  100       1.40
# 2 g-computation  200       2.72
# 3 g-computation  500       7.01
# 4 g-computation 1000      15.78
# 5 TMLE           100       2.61
# 6 TMLE           200       5.17
# 7 TMLE           500      12.83
# 8 TMLE          1000      28.45

# %%
ggplot(data, aes(x = n_samples, y = duration, group = estimator)) +
  geom_point(aes(shape = estimator, color = estimator)) +
  geom_line(aes(color = estimator))
# Out:
# plot without title

# %%
data <- data.frame(read.csv("medoutcon.csv"))
data
# Out:
#   estimator n_samples direct_effect indirect_effect
# 1 one-step   100        6.01          8.63
# 2 one-step   200       16.83         16.40
# 3 one-step   500       53.67         49.75
# 4 one-step  1000      167.16        100.31
# 5 TMLE       100        6.78          8.63
# 6 TMLE       200       15.05         15.73
# 7 TMLE       500       62.46         49.16
# 8 TMLE      1000      105.70        107.15

# %%
library(patchwork)

p1 <- ggplot(data, aes(x = n_samples, y = direct_effect, group = estimator)) +
  geom_point(aes(shape = estimator, color = estimator)) +
  geom_line(aes(color = estimator))
p2 <- ggplot(data, aes(x = n_samples, y = indirect_effect, group = estimator)) +
  geom_point(aes(shape = estimator, color = estimator)) +
  geom_line(aes(color = estimator))

combined <- p1 + p2 + plot_layout(guides = "collect") & theme(legend.position = "right")
combined
# Out:
# plot without title

# %%
data <- data.frame(read.csv("iptw_gcomp.csv"))
data
# Out:
#   estimator     n_samples duration
# 1 IPTW           100       13.81
# 2 IPTW           200       26.91
# 3 IPTW           500       68.42
# 4 IPTW          1000      140.54
# 5 g-computation  100       12.28
# 6 g-computation  200       24.58
# 7 g-computation  500       61.42
# 8 g-computation 1000      121.49

# %%
ggplot(data, aes(x = n_samples, y = duration, group = estimator)) +
  geom_point(aes(shape = estimator, color = estimator)) +
  geom_line(aes(color = estimator))
# Out:
# plot without title

# %%
data <- data.frame(read.csv("medoutcon_all.csv"))
data
# Out:
#    effect   estimator learner  n_sim duration bias          variance
# 1  direct   one-step  glm_fast 100    28       0.0006863745 2.774893e-04
# 2  direct   one-step  glm_fast 200    66      -0.0004494406 2.702406e-04
# 3  direct   one-step  hal      100    60       0.0006827346 2.709446e-04
# 4  direct   one-step  hal      200   127      -0.0004697120 2.727083e-04
# 5  direct   TMLE      glm_fast 100    28      -0.0095489320 3.930228e-04
# 6  direct   TMLE      glm_fast 200    66      -0.0098637800 3.822515e-04
# 7  direct   TMLE      hal      100    60      -0.0092594800 3.779163e-04
# 8  direct   TMLE      hal      200   127      -0.0099211310 3.772731e-04
# 9  indirect one-step  glm_fast 100    28       0.0011894450 1.975820e-05
# 10 indirect one-step  glm_fast 200    66       0.0007298047 1.804866e-05
# 11 indirect one-step  hal      100    60       0.0012204110 1.935189e-05
# 12 indirect one-step  hal      200   127       0.0009272753 1.741075e-05
# 13 indirect TMLE      glm_fast 100    28       0.0010832670 1.649212e-05
# 14 indirect TMLE      glm_fast 200    66       0.0008086020 1.664688e-05
# 15 indirect TMLE      hal      100    60       0.0011480050 1.739804e-05
# 16 indirect TMLE      hal      200   127       0.0011122600 1.616048e-05
#    std         std_bias    mse          av_est_std  coverage
# 1  0.016658010  0.04120387 2.779604e-04 0.015395810 0.940
# 2  0.016439000 -0.02733990 2.704426e-04 0.015402420 0.945
# 3  0.016460390  0.04147741 2.714107e-04 0.015356580 0.940
# 4  0.016513880 -0.02844346 2.729290e-04 0.015372740 0.935
# 5  0.019824800 -0.48166590 4.842049e-04 0.015378760 0.810
# 6  0.019551250 -0.50450880 4.795457e-04 0.015397670 0.835
# 7  0.019440070 -0.47630900 4.636542e-04 0.015349950 0.860
# 8  0.019423520 -0.51077920 4.757020e-04 0.015361340 0.825
# 9  0.004445020  0.26759060 2.117298e-05 0.004523985 0.990
# 10 0.004248371  0.17178460 1.858127e-05 0.004537201 0.965
# 11 0.004399078  0.27742430 2.084129e-05 0.004528392 0.910
# 12 0.004172619  0.22222860 1.827059e-05 0.004543031 0.980
# 13 0.004061050  0.26674550 1.766559e-05 0.004350968 0.970
# 14 0.004080059  0.19818390 1.730072e-05 0.004373933 0.965
# 15 0.004171096  0.27522870 1.871596e-05 0.004365288 0.960
# 16 0.004020010  0.27668090 1.739760e-05 0.004373798 0.970

# %%
data_direct <- data[data$effect == "direct", -c(5)]
data_direct
# Out:
#   effect estimator learner  n_sim bias          variance     std
# 1 direct one-step  glm_fast 100    0.0006863745 0.0002774893 0.01665801
# 2 direct one-step  glm_fast 200   -0.0004494406 0.0002702406 0.01643900
# 3 direct one-step  hal      100    0.0006827346 0.0002709446 0.01646039
# 4 direct one-step  hal      200   -0.0004697120 0.0002727083 0.01651388
# 5 direct TMLE      glm_fast 100   -0.0095489320 0.0003930228 0.01982480
# 6 direct TMLE      glm_fast 200   -0.0098637800 0.0003822515 0.01955125
# 7 direct TMLE      hal      100   -0.0092594800 0.0003779163 0.01944007
# 8 direct TMLE      hal      200   -0.0099211310 0.0003772731 0.01942352
#   std_bias    mse          av_est_std coverage
# 1  0.04120387 0.0002779604 0.01539581 0.940
# 2 -0.02733990 0.0002704426 0.01540242 0.945
# 3  0.04147741 0.0002714107 0.01535658 0.940
# 4 -0.02844346 0.0002729290 0.01537274 0.935
# 5 -0.48166590 0.0004842049 0.01537876 0.810
# 6 -0.50450880 0.0004795457 0.01539767 0.835
# 7 -0.47630900 0.0004636542 0.01534995 0.860
# 8 -0.51077920 0.0004757020 0.01536134 0.825

# %%
data_indirect <- data[data$effect == "indirect", -c(5)]
data_indirect
# Out:
#    effect   estimator learner  n_sim bias         variance     std
# 9  indirect one-step  glm_fast 100   0.0011894450 1.975820e-05 0.004445020
# 10 indirect one-step  glm_fast 200   0.0007298047 1.804866e-05 0.004248371
# 11 indirect one-step  hal      100   0.0012204110 1.935189e-05 0.004399078
# 12 indirect one-step  hal      200   0.0009272753 1.741075e-05 0.004172619
# 13 indirect TMLE      glm_fast 100   0.0010832670 1.649212e-05 0.004061050
# 14 indirect TMLE      glm_fast 200   0.0008086020 1.664688e-05 0.004080059
# 15 indirect TMLE      hal      100   0.0011480050 1.739804e-05 0.004171096
# 16 indirect TMLE      hal      200   0.0011122600 1.616048e-05 0.004020010
#    std_bias  mse          av_est_std  coverage
# 9  0.2675906 2.117298e-05 0.004523985 0.990
# 10 0.1717846 1.858127e-05 0.004537201 0.965
# 11 0.2774243 2.084129e-05 0.004528392 0.910
# 12 0.2222286 1.827059e-05 0.004543031 0.980
# 13 0.2667455 1.766559e-05 0.004350968 0.970
# 14 0.1981839 1.730072e-05 0.004373933 0.965
# 15 0.2752287 1.871596e-05 0.004365288 0.960
# 16 0.2766809 1.739760e-05 0.004373798 0.970

# %%
for (i in 5:11) {
  data_direct %>%
    group_by(estimator, learner) %>%
    ggplot(aes(x = n_sim, y = data_direct[, i], fill = estimator, color = estimator, shape = learner)) +
    geom_point(size=3) +
    geom_line() +
    ylab(colnames(data_direct)[i]) ->
  p
  print(p)
}
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title

# %%
for (i in 5:11) {
  data_indirect %>%
    group_by(estimator, learner) %>%
    ggplot(aes(x = n_sim, y = data_indirect[, i], fill = estimator, color = estimator, shape = learner)) +
    geom_point(size=3) +
    geom_line() +
    ylab(colnames(data_indirect)[i]) ->
  p
  print(p)
}
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
